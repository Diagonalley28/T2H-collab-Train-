# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a1510089-471e-40fe-86b3-3d9cbed07954" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1510089-471e-40fe-86b3-3d9cbed07954">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lha kaggle.json
# !pip install -q kaggle # installing the kaggle package
# !mkdir -p ~/.kaggle # creating .kaggle folder where the key should be placed
# !cp kaggle.json ~/.kaggle/ # move the key to the folder
# !pwd # checking the present working directory
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# -rw-r--r-- 1 root root 71 Feb 16 10:40 kaggle.json
# /content

# %%
# !kaggle datasets download -d vishalbsadanand/deepfashion-1
# !git clone https://github.com/yumingj/Text2Human.git
# !unzip deepfashion-1.zip -d Text2Human
# !cd Text2Human
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00003978-02_4_full.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00003989-02_1_front.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00003996-04_4_full.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00004004-05_4_full.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00004050-01_2_side.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00004050-01_3_back.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00004062-02_1_front.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00004065-02_4_full.png
#   inflating: Text2Human/datasets/train_images/WOMEN-Jackets_Coats-id_00004098-01_1_front.png
# ...

# %%
# !git clone https://github.com/yumingj/Text2Human.git
# %cd Text2Human
# Out:
# fatal: destination path 'Text2Human' already exists and is not an empty directory.
# /content/Text2Human

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py38_23.1.0-1-Linux-x86_64.sh
! chmod +x Miniconda3-py38_23.1.0-1-Linux-x86_64.sh
# !bash ./Miniconda3-py38_23.1.0-1-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2023-02-16 10:47:45--  https://repo.anaconda.com/miniconda/Miniconda3-py38_23.1.0-1-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68546682 (65M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_23.1.0-1-Linux-x86_64.sh’
#
# Miniconda3-py38_23. 100%[===================>]  65.37M   204MB/s    in 0.3s
#
# 2023-02-16 10:47:45 (204 MB/s) - ‘Miniconda3-py38_23.1.0-1-Linux-x86_64.sh’ saved [68546682/68546682]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# !conda env create -f ./environment/text2human_env.yaml
# !conda activate text2human
# !pip install mmcv-full==1.2.1 -f https://download.openmmlab.com/mmcv/dist/cu101/torch1.7.0/index.html
# !pip install mmsegmentation==0.9.0 
# !conda install -c huggingface tokenizers=0.9.4 -y
# !conda install -c huggingface transformers=4.0.0 -y
# !conda install -c conda-forge sentence-transformers=2.0.0 -y
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
# pytorch-1.7.1        | 553.7 MB  | :   1% 0.007506040483695588/1 [00:42<34:33, 2089.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1m       | 3.8 MB    | :  87% 0.8706110179387967/1 [00:42<00:02, 18.15s/it]
#
#
#
#
#
# python-3.6.13        | 33.9 MB   | :  16% 0.1615208376640094/1 [00:42<01:33, 111.24s/it]
#
#
#
#
#
#
#
# pytorch-1.7.1        | 553.7 MB  | :   1% 0.00756247687830984/1 [00:42<43:19, 2618.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1m       | 3.8 MB    | :  89% 0.887037640918774/1 [00:42<00:02, 18.24s/it]
#
#
#
#
#
# python-3.6.13        | 33.9 MB   | :  16% 0.16428976630967812/1 [00:42<01:28, 106.08s/it]
#
#
#
#
#
#
#
# pytorch-1.7.1        | 553.7 MB  | :   1% 0.0076753496675383455/1 [00:42<42:42, 2581.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1m       | 3.8 MB    | :  90% 0.9034642638987512/1 [00:42<00:01, 17.84s/it]
#
#
#
#
#
#
#
# ...

# %%
# !pip install tensorboard einops lpips 
# !apt-get update
# !apt-get upgrade libstdc++6
# !strings /usr/lib/x86_64-linux-gnu/libstdc++.so.6 | grep GLIBCXX

# %%
# !python train_parsing_gen.py -opt ./configs/parsing_gen.yml
# Out:
# gpu_list:  3
# 2023-02-16 11:04:01,404.404 - INFO:   name: parsing_generation
#   use_tb_logger: True
#   set_CUDA_VISIBLE_DEVICES: None
#   gpu_ids: [3]
#   batch_size: 8
#   num_workers: 4
#   segm_dir: ./datasets/segm
#   pose_dir: ./datasets/densepose
#   train_ann_file: ./datasets/shape_ann/train_ann_file.txt
#   val_ann_file: ./datasets/shape_ann/val_ann_file.txt
#   test_ann_file: ./datasets/shape_ann/test_ann_file.txt
#   downsample_factor: 2
#   model_type: ParsingGenModel
#   embedder_dim: 8
#   embedder_out_dim: 128
#   attr_class_num: [2, 4, 6, 5, 4, 3, 5, 5, 3, 2, 2, 2, 2, 2, 2]
#   encoder_in_channels: 1
#   fc_in_channels: 64
#   fc_in_index: 4
#   fc_channels: 64
#   fc_num_convs: 1
#   fc_concat_input: False
#   fc_dropout_ratio: 0.1
#   fc_num_classes: 24
#   fc_align_corners: False
#   val_freq: 5
#   print_freq: 100
#   weight_decay: 0
#   manual_seed: 2021
#   num_epochs: 100
#   lr: 0.0001
#   lr_decay: step
#   gamma: 0.1
#   step: 50
#   is_train: True
# ...

# %%
# !python train_vqvae.py -opt ./configs/vqvae_top.yml
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# gpu_list:  3
# 2023-02-15 07:56:48,601.601 - INFO:   name: vqvae_top
#   use_tb_logger: True
#   set_CUDA_VISIBLE_DEVICES: None
#   gpu_ids: [3]
#   batch_size: 4
#   num_workers: 4
#   train_img_dir: ./datasets/train_images
#   test_img_dir: ./datasets/test_images
#   segm_dir: ./datasets/segm
#   pose_dir: ./datasets/densepose
#   train_ann_file: ./datasets/texture_ann/train
#   val_ann_file: ./datasets/texture_ann/val
#   test_ann_file: ./datasets/texture_ann/test
#   downsample_factor: 2
#   model_type: VQImageSegmTextureModel
#   embed_dim: 256
#   n_embed: 1024
#   double_z: False
#   z_channels: 256
#   resolution: 512
#   in_channels: 3
#   out_ch: 3
#   ch: 128
#   ch_mult: [1, 1, 2, 2, 4]
#   num_res_blocks: 2
#   attn_resolutions: [32]
#   dropout: 0.0
#   disc_layers: 3
#   disc_weight_max: 0
#   disc_start_step: 3000000000000000000000000001
#   n_channels: 3
#   ndf: 64
#   nf: 128
#   perceptual_weight: 1.0
# ...

# %%
# !python train_vqvae.py -opt ./configs/vqvae_bottom.yml
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# gpu_list:  3
# 2023-02-15 07:56:51,614.614 - INFO:   name: vqvae_bottom
#   use_tb_logger: True
#   set_CUDA_VISIBLE_DEVICES: None
#   gpu_ids: [3]
#   batch_size: 4
#   num_workers: 4
#   train_img_dir: ./datasets/train_images
#   test_img_dir: ./datasets/test_images
#   segm_dir: ./datasets/segm
#   pose_dir: ./datasets/densepose
#   train_ann_file: ./datasets/texture_ann/train
#   val_ann_file: ./datasets/texture_ann/val
#   test_ann_file: ./datasets/texture_ann/test
#   downsample_factor: 2
#   model_type: HierarchyVQSpatialTextureAwareModel
#   embed_dim: 256
#   n_embed: 1024
#   codebook_spatial_size: 2
#   bot_n_embed: 512
#   bot_double_z: False
#   bot_z_channels: 256
#   bot_resolution: 512
#   bot_in_channels: 3
#   bot_out_ch: 3
#   bot_ch: 128
#   bot_ch_mult: [1, 1, 2, 4]
#   bot_num_res_blocks: 2
#   bot_attn_resolutions: [64]
#   bot_dropout: 0.0
#   top_double_z: False
#   top_z_channels: 256
# ...

# %%
# !python train_parsing_token.py -opt ./configs/parsing_token.yml
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# gpu_list:  3
# 2023-02-15 07:56:56,111.111 - INFO:   name: parsing_tokenization
#   use_tb_logger: True
#   set_CUDA_VISIBLE_DEVICES: None
#   gpu_ids: [3]
#   batch_size: 4
#   num_workers: 4
#   train_img_dir: ./datasets/train_images
#   test_img_dir: ./datasets/test_images
#   segm_dir: ./datasets/segm
#   pose_dir: ./datasets/densepose
#   train_ann_file: ./datasets/texture_ann/train
#   val_ann_file: ./datasets/texture_ann/val
#   test_ann_file: ./datasets/texture_ann/test
#   downsample_factor: 2
#   model_type: VQSegmentationModel
#   embed_dim: 32
#   n_embed: 1024
#   image_key: segmentation
#   n_labels: 24
#   double_z: False
#   z_channels: 32
#   resolution: 512
#   in_channels: 24
#   out_ch: 24
#   ch: 64
#   ch_mult: [1, 1, 2, 2, 4]
#   num_res_blocks: 1
#   attn_resolutions: [16]
#   dropout: 0.0
#   num_segm_classes: 24
#   val_freq: 5
#   print_freq: 100
#   weight_decay: 0
#   manual_seed: 2021
# ...

# %%
# !python train_sampler.py -opt ./configs/sampler.yml
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# gpu_list:  3
# 2023-02-15 07:57:00,316.316 - INFO:   name: sampler
#   use_tb_logger: True
#   set_CUDA_VISIBLE_DEVICES: None
#   gpu_ids: [3]
#   batch_size: 4
#   num_workers: 1
#   train_img_dir: ./datasets/train_images
#   test_img_dir: ./datasets/test_images
#   segm_dir: ./datasets/segm
#   pose_dir: ./datasets/densepose
#   train_ann_file: ./datasets/texture_ann/train
#   val_ann_file: ./datasets/texture_ann/val
#   test_ann_file: ./datasets/texture_ann/test
#   downsample_factor: 2
#   img_ae_path: ./pretrained_models/vqvae_top.pth
#   segm_ae_path: ./pretrained_models/parsing_token.pth
#   model_type: TransformerTextureAwareModel
#   img_embed_dim: 256
#   img_n_embed: 1024
#   img_double_z: False
#   img_z_channels: 256
#   img_resolution: 512
#   img_in_channels: 3
#   img_out_ch: 3
#   img_ch: 128
#   img_ch_mult: [1, 1, 2, 2, 4]
#   img_num_res_blocks: 2
#   img_attn_resolutions: [32]
#   img_dropout: 0.0
# ...

# %%
# !python train_index_prediction.py -opt ./configs/index_pred_net.yml
